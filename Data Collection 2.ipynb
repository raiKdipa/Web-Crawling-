# %%
import csv
import requests
from bs4 import BeautifulSoup

# Website URL
url = "https://www.evolvemediallc.com/privacy-policy.php"

# Send a GET request to the URL
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the target parent element with CSS selector 'div.privacy-policy-container'
parent_element = soup.select_one('div.privacy-policy-container')

# Find all "h1", "div", "p", and "li" elements inside the parent element
h1_elements = parent_element.select('h1')
div_elements = parent_element.select('div')
p_elements = parent_element.select('p')
li_elements = parent_element.select('li')

# Extract the text content from each element
scraped_data = [element.get_text(strip=True) for element in h1_elements + div_elements + p_elements + li_elements]

# Print the scraped data
for item in scraped_data:
    print(item)

# Save the scraped data into a CSV file
with open('evolvemediallc_privacy_2023.csv', 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)

    # Write the data to the CSV file
    writer.writerow(['Scraped Data'])
    writer.writerows([[item] for item in scraped_data])
# Out:
# This privacy policy was last modified on January 10, 2021 (the “Effective Date”).
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

# Website URL
url = "https://www.makeupalley.com/docs/content/privacypolicy"

# Send a GET request to the URL
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the target parent element with CSS selector 'div.container.doc-content'
parent_element = soup.select_one('div.container.doc-content')

# Find all "h1" and "div" elements inside the parent element
h1_elements = parent_element.select('h1')
div_elements = parent_element.select('div')

# Extract the text content from each element
scraped_data = [element.get_text(strip=True) for element in h1_elements + div_elements]

# Print the scraped data
for item in scraped_data:
    print(item)

# Save the scraped data into a CSV file
with open('makeupalley_privacy.csv', 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)

    # Write the data to the CSV file
    writer.writerow(['Scraped Data'])
    writer.writerows([[item] for item in scraped_data])
# Out:
# Privacy Policy
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://bitpay.com/about/privacy-eu/"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified class
parent_element = soup.select_one("div.legal-privacy-eu__inner")

# Find all "h1", "div", "p", "td", and "li" elements and get their text
text_elements = parent_element.select("h1, div, p, td, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "bitpay_privacy_policy_2023.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# EU Privacy NoticeUpdated May 19, 2020ScopeResponsibilityWhat is "personal data"?How we obtain personal dataWho are the data subjects?Details of data processingHow we protect and store personal informationData retentionHow we share personal data with third parties and transfers outside the EEAYour rightsMarketingContact InformationScopeThis EU Privacy Notice (“Notice”) describes the ways BitPay Inc. (“BitPay”, “we”, “us”, “our”) collects,
#               stores, uses and protects
#               personal data. BitPay’s services include Merchant processing services, websites, mobile applications,
#               products, and other features, technologies or functionalities, including customer support (the
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://www.blockchain.com/legal/privacy"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified attributes
parent_element = soup.select_one("main[spacing='7.25rem'].Layout__Main-sc-1jcfs2f-1.hXRSxy div.LegalPage__Page-exv7hv-3.epwlsj")

# Find all "h1", "div", "p", and "li" elements and get their text
text_elements = parent_element.select("h1, div, p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "blockchain_privacy_policy_2023.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# Legal CenterAs the world’s leading crypto finance house serving tens of millions of customers, protecting the security and privacy of our users is our top priority.
# Legal CenterAs the world’s leading crypto finance house serving tens of millions of customers, protecting the security and privacy of our users is our top priority.
# Legal CenterAs the world’s leading crypto finance house serving tens of millions of customers, protecting the security and privacy of our users is our top priority.
# Legal Center
# As the world’s leading crypto finance house serving tens of millions of customers, protecting the security and privacy of our users is our top priority.
# We are no longer able to provide custodial services in Canada. Unfortunately, due to developments in Canadian regulation impacting custody and exchanges, Blockchain.com is pausing the availability of custodial and exchange services to customers residing in Canada.
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://www.arsenal.com/privacy-policy#_Personal_data_Arsenal"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified class
parent_element = soup.select_one("div.node__content.article-body")

# Find all "h1", "div", "p", and "li" elements and get their text
text_elements = parent_element.select("h1, div, p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "arsenal_privacy_policy.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# SummaryThe Arsenal Football Club Plc (‘Arsenal’, ‘we’, ‘us’) is committed to protecting your personal data and handling it responsibly.This policy covers the personal data that Arsenal processes whenever you interact with us, including when you engage with us online (such as on social media or by using our websites and apps), when you attend events at Emirates Stadium, and when you correspond with us (such as by email or over the phone).  It also covers personal data that we may receive from third parties.The sections below explain in more detail:the types of personal data we collect from youthe types of personal data we receive from third partieswhy we process your personal datawho we share your personal data withpersonal data transfers outside of the UKhow long we retain your personal datayour rights to withdraw your consent and to object (including to direct marketing)your other personal data rightshow to contact us and exercise your rightsIf you would like to know how we collect 
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://www.fcbarcelona.com/en/privacy-policy"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified ID
parent_element = soup.select_one("main#main")

# Find all "h1", "div", "p", and "li" elements and get their text
text_elements = parent_element.select("h1, div, p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "fcbarcelona_privacy_policy.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# Privacy Policy1.  DATA PROCESSORWhen registering, your personal data will be processed by FC Barcelona (hereinafter “FC Barcelona or Club), located at Calle Arístides Maillol s/n, 08028, Barcelona and with Spanish tax identification number (NIF) G-08266298.2.  PURPOSES AND GROUNDS OF LEGITIMATIONYour data will be processed for the following purposes:USEPURPOSEGROUNDS OF LEGITIMATION AND DURATIONREGISTRATION FOR CULEROn registration for Culer (hereinafter, “Culers” or “user/s”) FC Barcelona shall process your data to manage and maintain your user account and to provide access to certain free contents on Barça TV +.We process your data on the grounds of your consent when registering as a user.The data will be processed as long as you maintain your user account or if you oppose the processing.NEWSLETTERSIn addition, you may subscribe to the following newsletters, giving consent to each of them as part of the registration process.-    Newsletters about Culer, with information about FC Ba
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://www.liverpoolfc.com/legal/privacy-policy"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified ID, tabindex, and class
parent_element = soup.select_one("main#main[tabindex='-1'].css-3yjyo7")

# Find all "h1", "div", "p", and "li" elements and get their text
text_elements = parent_element.select("h1, div, p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "liverpoolfc_privacy_policy.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# LegalPrivacy PolicyWEBSITE PRIVACY NOTICEThis Privacy Notice explains in detail the types of personal data we may collect about you when you interact with us. It also explains how we’ll store and handle that data, and keep it safe.There’s a lot of information here, but we want you to be fully informed about your rights, and how Liverpool Football Club uses your data; for example, we will explain how we analyse and combine all the data we hold about you to ensure communications are personalised and relevant.We hope the following sections will answer any questions you have but if not, please do get in touch with us.Summary of how we use your dataOur website and app are designed to allow fans of Liverpool Football Club ("LFC", "we" or "us") to interact with the club. We use your personal data in various ways to facilitate this.LFC's use of your personal data allows us to provide products, tickets and services that you have purchased, to communicate with our fans, to provide you with inf
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://www.bbc.co.uk/usingthebbc/privacy-policy/"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified class
parent_element = soup.select_one("main.ise-c-main")

# Find all "h1", "div", "p", and "li" elements and get their text
text_elements = parent_element.select("h1, div, p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "bbc_privacy_policy.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# Contents1. What's in this policy?2. What does this policy cover?3. How do you protect my personal information?4. What types of personal information does the BBC collect about me?5. How long will the BBC keep my personal information?6. How can the BBC use my personal information?7. When will the BBC use my information to contact me?8. Will I be contacted for marketing purposes?9. When does the BBC share my personal information with others?10. What's different for kids and teens?11. Can I delete my information?12. What are my rights?13. How does the BBC use cookies and similar tracking?14. How will I find out about changes to this policy?15. How can I contact the BBC?Page updated: September 2022Version 3.21. What's in this policy?This policy is for when you're in the UK (view policy for when you're outside the UK). It tells you:what information we might collect about youhow we might use that informationwhen we might use your details to contact youwhat information of yours we might shar
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://www.irishtimes.com/policy-and-terms/privacy-policy/#:~:text=We%20process%20your%20personal%20information,not%20automatically%20override%20your%20interests"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified class
parent_element = soup.select_one("article.default__ArticleBody-sc-1nhbny4-2.kWWtWa.article-body-wrapper.article-sub-wrapper")

# Find all "h1", "div", "p", and "li" elements and get their text
text_elements = parent_element.select("h1, div, p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "irishtimes_privacy_policy.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# This privacy policy is effective as and from May 24th, 2022
# Introduction
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://www.booking.com/content/privacy.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaGmIAQGYAQm4AQfIAQzYAQHoAQH4AQuIAgGoAgO4As6JzaMGwAIB0gIkNzJiZWI2OTEtYTZjNi00ZDlhLWI0YmMtMDljOTljZDRlODFh2AIG4AIB&sid=8e126f17fab213da008c856ebb4d0752"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified class and data-testid attributes
parent_element = soup.select_one("div.privacy-statement[data-testid='privacy-statement-container']")

# Find all "p" and "li" elements and get their text
text_elements = parent_element.select("p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "booking_privacy_policy.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# 19 Dec 2022
# First things first – your privacy is important to us. That might be the kind of thing all these notices say, but we mean it. You place your trust in us by using Booking.com services and we value that trust. That means we’re committed to protecting and safeguarding your personal data. We act in our customers’ best interest and we are transparent about the processing of your personal data.
# This document (‘this Privacy Statement’ or ‘our Privacy Statement’) describes how we use and process your personal data, provided in a readable and transparent manner. It also tells you what rights you can exercise in relation to your personal data and how you can contact us. Please also read ourCookie Statement, which tells you how Booking.com uses cookies and other similar tracking technologies.
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = "https://tripadvisor.mediaroom.com/in-privacy-policy"

# Send a GET request to the URL and retrieve the HTML content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find the parent element with the specified class
parent_element = soup.select_one("div.content")

# Find all "p" and "li" elements and get their text
text_elements = parent_element.select("p, li")
text_contents = [element.get_text(strip=True) for element in text_elements]

# Print the text attribute for each element
for text in text_contents:
    print(text)

# Save the data to a CSV file
csv_filename = "tripadvisor_privacy_policy.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["text"])
    writer.writerows([[text] for text in text_contents])
# Out:
# Effective: January 1, 2023
# Tripadvisor LLC owns and operates an online platform that provides users with information, recommendations and services related to travel and leisure, including tools for researching and/or booking hotels, rentals and other accommodations, attractions and experiences, restaurants, flights, and cruises, among other leisure-related services. In this Statement, we refer to these as our “Services”.
# ...
